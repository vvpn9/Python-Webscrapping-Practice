# %%
import requests
from bs4 import BeautifulSoup
import urllib
import os
import time
import random
import numpy as np

# %%
# first we need to find out the change pattern of the url

# %%
user_agent = [ 
    "Mozilla/5.0 (compatible; Baiduspider/2.0; +http://www.baidu.com/search/spider.html)", 
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; AcooBrowser; .NET CLR 1.1.4322; .NET CLR 2.0.50727)", 
    "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Acoo Browser; SLCC1; .NET CLR 2.0.50727; Media Center PC 5.0; .NET CLR 3.0.04506)", 
    "Mozilla/4.0 (compatible; MSIE 7.0; AOL 9.5; AOLBuild 4337.35; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)", 
    "Mozilla/5.0 (Windows; U; MSIE 9.0; Windows NT 9.0; en-US)", 
    "Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 2.0.50727; Media Center PC 6.0)", 
    "Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET CLR 1.0.3705; .NET CLR 1.1.4322)", 
    "Mozilla/4.0 (compatible; MSIE 7.0b; Windows NT 5.2; .NET CLR 1.1.4322; .NET CLR 2.0.50727; InfoPath.2; .NET CLR 3.0.04506.30)", 
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3) Arora/0.3 (Change: 287 c9dfb30)", 
    "Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/527+ (KHTML, like Gecko, Safari/419.3) Arora/0.6", 
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8.1.2pre) Gecko/20070215 K-Ninja/2.1.1", 
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; zh-CN; rv:1.9) Gecko/20080705 Firefox/3.0 Kapiko/3.0", 
    "Mozilla/5.0 (X11; Linux i686; U;) Gecko/20070322 Kazehakase/0.4.5", 
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.8) Gecko Fedora/1.9.0.8-1.fc10 Kazehakase/0.5.6", 
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.56 Safari/535.11", 
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.20 (KHTML, like Gecko) Chrome/19.0.1036.7 Safari/535.20", 
    "Opera/9.80 (Macintosh; Intel Mac OS X 10.6.8; U; fr) Presto/2.9.168 Version/11.52"
]

# %%
address = str(1049732)

# %%
def gethtml(index,number):
    url = f'https://movie.douban.com/celebrity/{number}/photos/?type=C&start=' + str(index)
    res = requests.get(url,headers={'User-Agent':random.choice(user_agent)})
    soup = BeautifulSoup(res.text, 'html.parser')
    return soup

# %%
images = []

# %%
# get the # of pics on the first page
imagecount = len(gethtml(0,address).find('ul', class_ = 'poster-col3 clearfix').find_all('img'))

# %%
print(imagecount)
# Out:
# 30

# %%
def delAll(path):
    if os.path.isdir(path):
        files = os.listdir(path)
        # 遍历并删除文件
        for file in files:
            p = os.path.join(path, file)
            if os.path.isdir(p):
                # 递归
                delAll(p)
            else:
                os.remove(p)
        # 删除文件夹
        os.rmdir(path)
    else:
        os.remove(path)

# %%
def getImages(pageNum,name,number):
    if os.path.exists(name):
        delAll(name)
    os.mkdir(name)
    global address,images,imgLen
    for k in range(pageNum):
        # 1、存储soup对象
        eachsoup = gethtml(k*imagecount,number)
        # 2、获取图片列表父元素
        imageList = eachsoup.find('ul', attrs={'class': "poster-col3 clearfix"})
        # 3、获取所有image
        #     通过extend方法，还是一个list，如果用append会是多个list，下面的循环的就要额外处理了
        images.extend(imageList.find_all('img'))
    #3、用循环处理所有li内的具体内容
    for i in range(len(images)):
        try:
            #获取图片后缀名，防止真实网址图片为png，jpg，gif等格式
            suffix = images[i]['src'][-3:]
            image_name = str(i+1)+'.'+suffix
            print(images[i]['src'])
            print(image_name)
            
            # urllib.request.urlretrieve(url, filename=None, reporthook=None, data=None)
            # 将URL表示的网络对象复制到本地文件。如果URL指向本地文件，则对象将不会被复制，除非提供文件名
            
            urllib.request.urlretrieve(images[i]['src'],name + "/" + image_name)      
            time.sleep(np.random.rand())
        except Exception as error:
            print(error)
            print('Save file error!')
    print('Data fetching finished')

# %%
address = str(1004572)
getImages(3,'Gabrielle Anwar',address)
# Out:
# https://img3.doubanio.com/view/photo/m/public/p739896780.jpg
# 1.jpg
# https://img9.doubanio.com/view/photo/m/public/p837800274.jpg
# 2.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2201978846.jpg
# 3.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2201978813.jpg
# 4.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2209387148.jpg
# 5.jpg
# https://img9.doubanio.com/view/photo/m/public/p1668258645.jpg
# 6.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2201978708.jpg
# 7.jpg
# https://img3.doubanio.com/view/photo/m/public/p2215224500.jpg
# 8.jpg
# https://img1.doubanio.com/view/photo/m/public/p837802379.jpg
# 9.jpg
# https://img1.doubanio.com/view/photo/m/public/p837802588.jpg
# 10.jpg
# https://img9.doubanio.com/view/photo/m/public/p837802445.jpg
# 11.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2217742378.jpg
# 12.jpg
# https://img2.doubanio.com/view/photo/m/public/p2223014102.jpg
# 13.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2217742369.jpg
# 14.jpg
# https://img9.doubanio.com/view/photo/m/public/p2207333925.jpg
# 15.jpg
# HTTP Error 418:
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p2584042011.jpg
# 16.jpg
# https://img9.doubanio.com/view/photo/m/public/p2530971044.jpg
# 17.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p1668258589.jpg
# 18.jpg
# https://img1.doubanio.com/view/photo/m/public/p837802269.jpg
# 19.jpg
# https://img1.doubanio.com/view/photo/m/public/p2215223649.jpg
# 20.jpg
# https://img1.doubanio.com/view/photo/m/public/p2207333947.jpg
# 21.jpg
# https://img1.doubanio.com/view/photo/m/public/p2201978837.jpg
# 22.jpg
# https://img9.doubanio.com/view/photo/m/public/p1969297176.jpg
# 23.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2215223577.jpg
# 24.jpg
# https://img9.doubanio.com/view/photo/m/public/p1969297556.jpg
# 25.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p1668258362.jpg
# 26.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2217742335.jpg
# 27.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2154569829.jpg
# 28.jpg
# https://img3.doubanio.com/view/photo/m/public/p2223014120.jpg
# 29.jpg
# https://img2.doubanio.com/view/photo/m/public/p2223013722.jpg
# 30.jpg
# HTTP Error 418:
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p2207334090.jpg
# 31.jpg
# https://img1.doubanio.com/view/photo/m/public/p837799997.jpg
# 32.jpg
# https://img3.doubanio.com/view/photo/m/public/p2530980021.jpg
# 33.jpg
# https://img9.doubanio.com/view/photo/m/public/p2530971055.jpg
# 34.jpg
# HTTP Error 418:
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p1969297671.jpg
# 35.jpg
# HTTP Error 418: I'm a teapot
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p1668259728.jpg
# 36.jpg
# https://img2.doubanio.com/view/photo/m/public/p1668258463.jpg
# 37.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2530980013.jpg
# 38.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2223014162.jpg
# 39.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2223014118.jpg
# 40.jpg
# https://img3.doubanio.com/view/photo/m/public/p2217742421.jpg
# 41.jpg
# https://img2.doubanio.com/view/photo/m/public/p1969296853.jpg
# 42.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2537867127.jpg
# 43.jpg
# https://img2.doubanio.com/view/photo/m/public/p2530980053.jpg
# 44.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2530980039.jpg
# 45.jpg
# https://img3.doubanio.com/view/photo/m/public/p2223014171.jpg
# 46.jpg
# https://img9.doubanio.com/view/photo/m/public/p2223014144.jpg
# 47.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2223014108.jpg
# 48.jpg
# https://img3.doubanio.com/view/photo/m/public/p2223013920.jpg
# 49.jpg
# HTTP Error 418: I'm a teapot
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2223013912.jpg
# 50.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2223013899.jpg
# 51.jpg
# https://img2.doubanio.com/view/photo/m/public/p2223013892.jpg
# 52.jpg
# HTTP Error 418:
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p2223013881.jpg
# 53.jpg
# HTTP Error 418: I'm a teapot
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2217742402.jpg
# 54.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2217742293.jpg
# 55.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2215223592.jpg
# 56.jpg
# HTTP Error 418:
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p2215223571.jpg
# 57.jpg
# HTTP Error 418: I'm a teapot
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p2209387150.jpg
# 58.jpg
# HTTP Error 418: I'm a teapot
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2207333922.jpg
# 59.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p1969297845.jpg
# 60.jpg
# HTTP Error 418:
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p1969297691.jpg
# 61.jpg
# https://img9.doubanio.com/view/photo/m/public/p1851354306.jpg
# 62.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p1668259862.jpg
# 63.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p1668258828.jpg
# 64.jpg
# https://img2.doubanio.com/view/photo/m/public/p837802833.jpg
# 65.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2530980032.jpg
# 66.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2530980005.jpg
# 67.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2530980002.jpg
# 68.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2530979994.jpg
# 69.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2530978999.jpg
# 70.jpg
# https://img2.doubanio.com/view/photo/m/public/p2530978993.jpg
# 71.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2530978986.jpg
# 72.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2530978972.jpg
# 73.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2530978959.jpg
# 74.jpg
# https://img2.doubanio.com/view/photo/m/public/p2530978943.jpg
# 75.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2530978922.jpg
# 76.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2530978887.jpg
# 77.jpg
# https://img9.doubanio.com/view/photo/m/public/p2530978856.jpg
# 78.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2530971107.jpg
# 79.jpg
# https://img9.doubanio.com/view/photo/m/public/p2530971094.jpg
# 80.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2530971086.jpg
# 81.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2530971085.jpg
# 82.jpg
# HTTP Error 418:
# Save file error!
# https://img3.doubanio.com/view/photo/m/public/p2530971070.jpg
# 83.jpg
# HTTP Error 418: I'm a teapot
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2530971065.jpg
# 84.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2509227169.jpg
# 85.jpg
# https://img2.doubanio.com/view/photo/m/public/p2223013853.jpg
# 86.jpg
# HTTP Error 418:
# Save file error!
# https://img2.doubanio.com/view/photo/m/public/p2223013832.jpg
# 87.jpg
# HTTP Error 418:
# Save file error!
# https://img1.doubanio.com/view/photo/m/public/p2223013739.jpg
# 88.jpg
# https://img2.doubanio.com/view/photo/m/public/p2217743043.jpg
# 89.jpg
# HTTP Error 418:
# Save file error!
# https://img9.doubanio.com/view/photo/m/public/p2217742415.jpg
# 90.jpg
# HTTP Error 418:
# Save file error!
# Data fetching finished
